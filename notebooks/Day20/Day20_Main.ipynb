# %% [markdown]
# # Main Notebook

# %% [markdown]
# This notebook is for orchestration purposes. We wil be calling following notebooks:
# - Day20_NB1.ipynb
# - Day20_NB2.ipynb
# - Day20_functions.ipynb
# - Day20_NB3_Widget.ipynb
# - Day20_Main.ipynb (this document)

# %% [markdown]
# Run notebook 1 - Day20_NB1
# And get the results back

# %%
# %run /Users/tomaz.kastrun@gmail.com/Day20/Day20_NB1

# %% [markdown]
# Load functions from notebook Day20_functions

# %%
# %run /Users/tomaz.kastrun@gmail.com/Day20/Day20_functions

# %% [markdown]
# Consume loaded functions from notebook: Day20_functions in this notebook: Day20_Main

# %%
num1 = 100
num2 = 400

print("The sum is", add_numbers(num1, num2))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">The sum is 500
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
current_time()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Current date and time = 2020-12-19 16:30:54.313591
# </div>

# %% [markdown]
# Now let's also create Table to store results of notebook run
# Only Daily20_NB2 has a SQL INSERT Command

# %%
# %sql
DROP TABLE IF EXISTS day10.day20_NB_run;
CREATE TABLE day10.day20_NB_run (id INT, NB_Name STRING, Run_time TIMESTAMP)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
INSERT INTO day10.day20_NB_run VALUES (10, "Running from day20_Main notebook", CAST(current_timestamp() AS TIMESTAMP))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql SELECT * FROM day10.day20_NB_run
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>NB_Name</th><th>Run_time</th></tr></thead><tbody><tr><td>10</td><td>Running from day20_Main notebook</td><td>2020-12-19T16:31:05.868+0000</td></tr></tbody></table></div>

# %%
# %run /Users/tomaz.kastrun@gmail.com/Day20/Day20_NB2

# %% [markdown]
# Check the results of insert statement from notebook2

# %%
# %sql SELECT * FROM day10.day20_NB_run
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>NB_Name</th><th>Run_time</th></tr></thead><tbody><tr><td>10</td><td>Running from day20_Main notebook</td><td>2020-12-19T16:31:05.868+0000</td></tr><tr><td>10</td><td>Running from Day20_Notebook2</td><td>2020-12-19T00:00:00.000+0000</td></tr></tbody></table></div>

# %% [markdown]
# Passing the arguments with values from this notebook (Day20_Main)  to notebook Day20_NB3_Widget

# %%
dbutils.notebook.run("Day20_NB3_Widget", 60, {"Wid_arg": "5"})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Check if the previous execution of running notebooks have been succesful

# %%
# %sql SELECT * FROM day10.day20_NB_run
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>NB_Name</th><th>Run_time</th></tr></thead><tbody><tr><td>10</td><td>Running from day20_Main notebook</td><td>2020-12-19T16:31:05.868+0000</td></tr><tr><td>10</td><td>Running from day20_Widget notebook</td><td>2020-12-19T00:00:00.000+0000</td></tr><tr><td>10</td><td>Running from Day20_Notebook2</td><td>2020-12-19T00:00:00.000+0000</td></tr></tbody></table></div>
